# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/olist_products_dataset.csv")

# %%
df[df["product_photos_qty"] == 225.0]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm, product_category_name]
# Index: []

# %%
cols = [
    "product_name_lenght",
    "product_description_lenght",
    "product_photos_qty"
]


df[cols] = df[cols].astype("Int64")
# df[cols] = df[cols].fillna(-100)
# df[cols] = df[cols].astype("int64") 
# df[cols] = df[cols].replace(-100, np.nan)
# for i in cols: 
    # if df[i].isna().values:/
        # print(df[i])
    # print(df[i].isna().values)
    # if pd.isna(df[i]):
        # continue
    # df[i] = df[i].astype(int)
    #

# %%
df
# Out:
#                              product_id  product_name_lenght  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1      3aa071139cb16b67ca9e5dea641aaa2f                 44.0
# 2      96bd76ec8810374ed1b65e291975717f                 46.0
# 3      cef67bcfe19066a932b7673e239eb23d                 27.0
# 4      9dc1a7de274444849c219cff195d0b71                 37.0
# ...                                 ...                  ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                 45.0
# 32947  bf4538d88321d0fd4412a93c974510e6                 41.0
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                 50.0
# 32949  83808703fc0706a22e264b9d75f04a2e                 60.0
# 32950  106392145fca363410d287a815be6de4                 58.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                           287.0                 1.0             225.0
# 1                           276.0                 1.0            1000.0
# ...

# %%
df.to_csv("./data/olist_products_dataset.csv", index=False)
